# %% [markdown]
# # Supply Chain Optimization - Interactive Demo
#
# **EXPERIMENTAL RESEARCH PROJECT - NOT FOR AUTOMATED DECISIONS WITHOUT HUMAN REVIEW**
#
# This notebook demonstrates supply chain optimization techniques for educational and research purposes. All optimization results require human review before implementation in production systems.
#
# ## Overview
#
# This notebook covers:
# 1. **Transportation Optimization**: Classic transportation problem solving
# 2. **Inventory Management**: Multi-echelon inventory optimization
# 3. **Workforce Planning**: Employee-task assignment optimization
# 4. **Demand Forecasting**: Time series forecasting for supply chain planning
# 5. **What-If Analysis**: Scenario planning and sensitivity analysis
#
# ## Setup and Configuration
